# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sci

# %%
U = np.array([0, 2.9, 4.5, 5.9, 7.4, 9.1, 11.9])
I = np.array([0, 29, 44, 58, 73, 89, 117])

# %%
# %matplotlib inline

fig = plt.figure(figsize=(24,12))
ax = fig.add_subplot()

major_ticks_top = np.linspace(0,12,13)
minor_ticks_top = np.linspace(0,12,241)
major_ticks_bottom = np.linspace(0,120,25)
minor_ticks_bottom = np.linspace(0,120,241)

# LA GRILLE
ax.set_xticks(major_ticks_bottom)
ax.set_yticks(major_ticks_top)
ax.set_xticks(minor_ticks_bottom, minor=True)
ax.set_yticks(minor_ticks_top, minor=True)
ax.grid(which='major', alpha=0.6, color='cornflowerblue')
ax.grid(which='minor', alpha=0.3, color='cornflowerblue')

# %%
# %matplotlib inline
cm = 1/2.54  # centimeters in inches
fig = plt.figure(figsize=(24/cm,12/cm))
ax = fig.add_subplot()

major_ticks_top = np.linspace(0,12,13)
minor_ticks_top = np.linspace(0,12,121)
major_ticks_bottom = np.linspace(0,120,25)
minor_ticks_bottom = np.linspace(0,120,241)

# LA GRILLE
ax.set_xticks(major_ticks_bottom)
ax.set_yticks(major_ticks_top)
ax.set_xticks(minor_ticks_bottom, minor=True)
ax.set_yticks(minor_ticks_top, minor=True)
ax.grid(which='major', alpha=0.9, color='cornflowerblue', lw=5)
ax.grid(which='minor', alpha=0.5, color='cornflowerblue', lw=2)


# LE PLOT
ax.plot(I,U,'r+-', ms=40, mec='k', mew=7, lw=5)


# LES AXES
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_position(('data',0))
ax.spines['bottom'].set_position(('data',0))

# We change the fontsize of minor ticks label 
ax.tick_params(axis='both', which='major', length=10, width=3, labelsize=40)

#LA RÉGRESSION LINÉAIRE
droite = sci.linregress(I,U)
coeff = droite.slope
print("coefficient directeur :", coeff)
ord_orig = droite.intercept
print("Ordonnée à l'origine :", ord_orig)

plt.show()
# Out:
# coefficient directeur : 0.10195241096753861
# Ordonnée à l'origine : -0.01435549952726145

# %%
# %matplotlib notebook
import mplcursors
cm = 1/2.54  # centimeters in inches
fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot()

major_ticks_top = np.linspace(0,12,13)
minor_ticks_top = np.linspace(0,12,120)
major_ticks_bottom = np.linspace(0,120,25)
minor_ticks_bottom = np.linspace(0,120,121)

# LA GRILLE
ax.set_xticks(major_ticks_bottom)
ax.set_yticks(major_ticks_top)
ax.set_xticks(minor_ticks_bottom, minor=True)
ax.set_yticks(minor_ticks_top, minor=True)
ax.grid(which='major', alpha=0.5, color='cornflowerblue', lw=3)
ax.grid(which='minor', alpha=0.2, color='cornflowerblue', lw=1)


# LE PLOT
ax.plot(I,U,'r+-', ms=20, mec='k', mew=2, lw=1)
mplcursors.cursor(hover=True)

# LES AXES
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_position(('data',0))
ax.spines['bottom'].set_position(('data',0))
# We change the fontsize of minor ticks label 
ax.tick_params(axis='both', which='major', length=5, width=3, labelsize=10)

#LA RÉGRESSION LINÉAIRE
droite = sci.linregress(I,U)
coeff = droite.slope
print("coefficient directeur :", coeff)
ord_orig = droite.intercept
print("Ordonnée à l'origine :", ord_orig)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1064">
# coefficient directeur : 0.10195241096753861
# Ordonnée à l'origine : -0.01435549952726145

# %%
# %matplotlib notebook
import mplcursors
fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot()

major_ticks_top = np.linspace(0,12,13)
minor_ticks_top = np.linspace(0,12,120)
major_ticks_bottom = np.linspace(0,120,25)
minor_ticks_bottom = np.linspace(0,120,241)

# LA GRILLE
ax.set_xticks(major_ticks_bottom)
ax.set_yticks(major_ticks_top)
ax.set_xticks(minor_ticks_bottom, minor=True)
ax.set_yticks(minor_ticks_top, minor=True)
ax.grid(which='major', alpha=0.9, color='cornflowerblue', lw=1.25)
ax.grid(which='minor', alpha=0.5, color='cornflowerblue', lw=0.8)

# LE PLOT
ax.scatter(I,U, color='red', marker='+', label='valeurs mesurées')
leg = ax.legend(facecolor='orange', shadow=True)
mplcursors.cursor(hover=True)
ax.set_axisbelow(True)

# LES AXES
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_position(('data',0))
ax.spines['bottom'].set_position(('data',0))

# We change the fontsize of minor ticks label 
#ax.tick_params(axis='both', which='major', length=10, width=3, labelsize=40)
# Out:
# <img src="data:image/png;base64,..." width="864">
